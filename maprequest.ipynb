# %%
import folium
import gpxpy

# Step 1: Load GPX file and extract markers (waypoints)
gpx_file_path = r'C:\Users\Umar Yahaya\iMMAP\Africa - Yola - Adamawa State\UNHCR\extracted_files\markers.gpx'

# Read the GPX file and extract the waypoints
with open(gpx_file_path, 'r') as gpx_file:
    gpx = gpxpy.parse(gpx_file)

# Extract latitude, longitude, and optional name/description from GPX waypoints
latitudes = [waypoint.latitude for waypoint in gpx.waypoints]
longitudes = [waypoint.longitude for waypoint in gpx.waypoints]
names = [waypoint.name if waypoint.name else "No name" for waypoint in gpx.waypoints]  # Add names or placeholders

# Calculate the center of the map (mean of latitudes and longitudes)
center_lat = sum(latitudes) / len(latitudes)
center_lon = sum(longitudes) / len(longitudes)

# Step 2: Create a Folium map centered around the markers with OpenStreetMap as the basemap
m = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles="OpenStreetMap")

# Step 3: Add GPX markers to the map with tooltips and contextual names
for lat, lon, name in zip(latitudes, longitudes, names):
    folium.Marker(
        [lat, lon],
        popup=f"Location: {lat}, {lon}",
        tooltip=name,  # Add tooltip with the name of the waypoint
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Step 4: Save the map as an HTML file
m.save('maprequest_unhcr.html')

# Display the map inline (if using JupyterLab or notebooks)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1e5be546e0735753031e65259c4fe04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1e5be546e0735753031e65259c4fe04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1e5be546e0735753031e65259c4fe04 = L.map(
#                 &quot;map_c1e5be546e0735753031e65259c4fe04&quot;,
#                 {
#                     center: [10.571975296319012, 13.417350317791406],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e461e76d420532b5c96636a3bb74d1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2e461e76d420532b5c96636a3bb74d1c.addTo(map_c1e5be546e0735753031e65259c4fe04);
#
#
#             var marker_96009093a8abca56133338ae1ce0cfea = L.marker(
#                 [10.2657509, 13.2727032],
#                 {}
#             ).addTo(map_c1e5be546e0735753031e65259c4fe04);
#
#
#             var icon_788c43c4ed9ecbbaa1d1019844ff8d14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_96009093a8abca56133338ae1ce0cfea.setIcon(icon_788c43c4ed9ecbbaa1d1019844ff8d14);
#
#
#         var popup_8962cc8183f9d2907186b5fe35d5bd91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcc25eb22aaa6c8db6cb2a9b97bf1a23 = $(`&lt;div id=&quot;html_fcc25eb22aaa6c8db6cb2a9b97bf1a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: 10.2657509, 13.2727032&lt;/div&gt;`)[0];
#                 popup_8962cc8183f9d2907186b5fe35d5bd91.setContent(html_fcc25eb22aaa6c8db6cb2a9b97bf1a23);
#
#
#
#         marker_96009093a8abca56133338ae1ce0cfea.bindPopup(popup_8962cc8183f9d2907186b5fe35d5bd91)
#         ;
#
#
#
#
#             marker_96009093a8abca56133338ae1ce0cfea.bindTooltip(
#                 `&lt;div&gt;
#                      One Stop Shop Mubi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6fb05a89aa85f4aaf6ef572ceaee0c5 = L.marker(
#                 [10.2657496, 13.2727022],
#                 {}
#             ).addTo(map_c1e5be546e0735753031e65259c4fe04);
#
#
#             var icon_728c17aa322ebc7cde1c37cdd9952de7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e6fb05a89aa85f4aaf6ef572ceaee0c5.setIcon(icon_728c17aa322ebc7cde1c37cdd9952de7);
#
#
#         var popup_87ee21828c54e5e9354ca715eb48cf64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb613161d09e03039298715ae352a7f4 = $(`&lt;div id=&quot;html_fb613161d09e03039298715ae352a7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: 10.2657496, 13.2727022&lt;/div&gt;`)[0];
#                 popup_87ee21828c54e5e9354ca715eb48cf64.setContent(html_fb613161d09e03039298715ae352a7f4);
#
#
#
#         marker_e6fb05a89aa85f4aaf6ef572ceaee0c5.bindPopup(popup_87ee21828c54e5e9354ca715eb48cf64)
#         ;
#
#
#
#
#             marker_e6fb05a89aa85f4aaf6ef572ceaee0c5.bindTooltip(
#                 `&lt;div&gt;
#                      My Position
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3cc113f6afa1b007c85cc2666cd05651 = L.marker(
#                 [10.265751, 13.2727027],
#                 {}
#             ).addTo(map_c1e5be546e0735753031e65259c4fe04);
#
#
#             var icon_3358f281b68dc4179788175c498d9f0f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3cc113f6afa1b007c85cc2666cd05651.setIcon(icon_3358f281b68dc4179788175c498d9f0f);
#
#
#         var popup_93c8c32a44f48fa21879887195b04a96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fb35c4bf036b8005f5763746ef64f00 = $(`&lt;div id=&quot;html_8fb35c4bf036b8005f5763746ef64f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: 10.265751, 13.2727027&lt;/div&gt;`)[0];
#                 popup_93c8c32a44f48fa21879887195b04a96.setContent(html_8fb35c4bf036b8005f5763746ef64f00);
#
#
#
#         marker
